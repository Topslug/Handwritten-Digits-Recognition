# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from common.trainer import Trainer
import pickle

(x_train, t_train), (x_test, t_test) = load_mnist(flatten=False)

# 시간이 오래 걸릴 경우 데이터를 줄인다.
x_train, t_train = x_train[:5000], t_train[:5000]
x_test, t_test = x_test[:1000], t_test[:1000]

# %%
from test_convnet_dropout import TestConvNet, TestConvNet_Dropout

# %%
network_list = []
trainer_list = []
has_dropout = ["no_dropout", "dropout"]
for i, network in enumerate([TestConvNet(), TestConvNet_Dropout()]):
    network.load_params("test_convnet_" + has_dropout[i].lower() + "_params.pkl")
    network_list.append(network)
    with open("trainer_" + has_dropout[i].lower() + ".pkl", 'rb') as f:
        trainer = pickle.load(f)
    trainer_list.append(trainer)

# %%
for i, has_dropout in enumerate(['no_dropout','dropout']):
    trainer = trainer_list[i]
    plt.plot(trainer.train_loss_list, label=has_dropout)
plt.xlabel("iterations")
plt.ylabel("loss")
plt.legend()
plt.show()

# %%
def show_accuracy_history(title, trainer):
    plt.title(title)
    plt.plot(trainer.train_acc_list, label='train', marker='o', markevery=2)
    plt.plot(trainer.test_acc_list, label='test', marker='s', markevery=2)
    plt.xlabel("epochs")
    plt.ylabel("loss")
    plt.legend()
    plt.show()

# %%
for i, has_dropout in enumerate(['dropout', 'no_dropout']):
    trainer = trainer_list[i]
    show_accuracy_history(has_dropout, trainer)
    
for i, has_dropout in enumerate(['dropout', 'no_dropout']):
    network = network_list[i]
    print(has_dropout + " : " + str(network.accuracy(x_test, t_test)))
# Out:
# dropout : 0.964
# no_dropout : 0.964
